# %% [markdown]
# # Méthode de dichotomie

# %% [markdown]
# Appliqueé à la fonction f: $x\longmapsto e^{\frac{-x^2}{2}}-x$ sur l'intervalle $[0,1]$

# %%
import numpy as np 
from matplotlib import pyplot as plt,animation as anim

# %%
f=lambda x:np.exp(-x**2/2)-x
x=np.linspace(0,1,100)
plt.plot(x,f(x))
plt.plot(x,[0]*len(x))

# %%
def dichotomie(f,a,b):
    x=a
    y=b
    while True:
        mid=(x+y)/2
        yield mid
        if(f(mid)==0):
            break
        if f(x)*f(mid)<=0:
            y=mid
        else:
            x=mid

# %%
(a,b)=(0,1)
dico=dichotomie(f,a,b)
alpha=0
x_dicho=[]
try :
    
    for i in range(100):
        alpha=next(dico)
        x_dicho.append(alpha)
        print(str(i)+"  "+str(alpha))
except:
    pass
# Out:
# 0  0.5
# 1  0.75
# 2  0.875
# 3  0.8125
# 4  0.78125
# 5  0.765625
# 6  0.7578125
# 7  0.75390625
# 8  0.751953125
# 9  0.7529296875
# 10  0.75341796875
# 11  0.753173828125
# 12  0.7530517578125
# 13  0.75311279296875
# 14  0.753082275390625
# 15  0.7530975341796875
# 16  0.7530899047851562
# 17  0.7530860900878906
# 18  0.7530879974365234
# 19  0.7530889511108398
# 20  0.753089427947998
# 21  0.753089189529419
# 22  0.7530890703201294
# 23  0.7530891299247742
# 24  0.7530891597270966
# 25  0.7530891746282578
# 26  0.7530891671776772
# 27  0.7530891634523869
# 28  0.753089165315032
# 29  0.7530891643837094
# 30  0.7530891648493707
# 31  0.7530891650822014
# 32  0.753089164965786
# 33  0.7530891650239937
# 34  0.7530891649948899
# 35  0.753089164980338
# 36  0.753089164973062
# 37  0.7530891649767
# 38  0.753089164978519
# 39  0.7530891649794285
# 40  0.7530891649798832
# 41  0.7530891649796558
# 42  0.7530891649797695
# 43  0.7530891649797127
# 44  0.7530891649796843
# ...

# %%
f(alpha)
# Out:
# 0.0

# %%
plt.plot(x,f(x))
plt.plot(x,[0]*len(x))
plt.plot(alpha,f(alpha),'bo')

# %% [markdown]
# Faire une animation

# %% [markdown]
# ## Méthode de point fixe

# %% [markdown]
# Appliqueé à la fonction g: $x\longmapsto \exp(-\frac{x^2}{2})$ sur l'intervalle $[0,1]$

# %% [markdown]
# $$ |g'(x)|=|-x\exp(-\frac{x^2}{2})|\leq e^{-\frac{1}{2}}<1 \quad \forall x \in [0,1] $$

# %%
g=lambda x:f(x)+x
#gprime=lambda x:x*np.exp(-x**2/2)

# %%
plt.plot(x,g(x))
#plt.plot(x,gprime(x))
plt.plot(x,x)

# %%
def point_fixe(g, x0):
    x1 = x0
    while True:
        x1 = g(x1)
        yield x1
        if x1==g(x1):
            break

# %%
xn=point_fixe(g,0)
x_ptf=[]
try :
    for i in range(100):
        alpha=next(xn)
        x_ptf.append(alpha)
        print("{}  {}".format(i,alpha))
except:
    pass
# Out:
# 0  1.0
# 1  0.6065306597126334
# 2  0.8319859539411386
# 3  0.7074415174158475
# 4  0.7786164235909729
# 5  0.7385091644489099
# 6  0.7613227538326822
# 7  0.7484086192455891
# 8  0.7557401108054124
# 9  0.751584557711938
# 10  0.7539421231295282
# 11  0.752605297049445
# 12  0.7533635492431814
# 13  0.7529335375194117
# 14  0.7531774241011009
# 15  0.7530391081416611
# 16  0.7531175539710631
# 17  0.7530730642223336
# 18  0.7530982963739179
# 19  0.7530839861571075
# 20  0.7530921021097746
# 21  0.7530874992046396
# 22  0.7530901097123571
# 23  0.7530886291807273
# 24  0.7530894688544062
# 25  0.7530889926391447
# 26  0.7530892627214453
# 27  0.753089109546084
# 28  0.7530891964184634
# 29  0.7530891471493767
# 30  0.7530891750920087
# 31  0.7530891592445325
# 32  0.7530891682323223
# 33  0.7530891631349577
# 34  0.7530891660258938
# 35  0.7530891643863188
# 36  0.7530891653161927
# 37  0.7530891647888209
# 38  0.7530891650879163
# 39  0.7530891649182864
# 40  0.7530891650144909
# ...

# %%
f(alpha)
# Out:
# 0.0

# %%
g(alpha)==alpha
# Out:
# True

# %%
plt.plot(x,g(x))
#plt.plot(x,gprime(x))
plt.plot(x,x)
plt.plot(alpha,alpha,'bo')

# %% [markdown]
# # méthode de la sécante

# %%
plt.plot(x,np.zeros(len(x)))
plt.plot(x,f(x))

# %%
def secante(f,a,b):
    x0=a
    x1=b
    while True:
        x2=(x1*f(x0)-x0*f(x1))/(f(x0)-f(x1))
        yield x2
        if f(x2)*(x0)<=0:
            x1=x2
        else:
            x0=x2
        if f(x2)==0:
            break

# %%
xnn=secante(f,a,b)
x_sec=[]
try:
    for i in range(40):
        alpha_sec=next(xnn)
        x_sec.append(alpha_sec)
        print(str(i)+"  "+str(alpha_sec))
except:
    pass
# Out:
# 0  0.717633299196792
# 1  0.759681095709554
# 2  0.7519082318540419
# 3  0.7533021902418798
# 4  0.7530507853633209
# 5  0.7530960811692058
# 6  0.7530879186994195
# 7  0.7530893895579198
# 8  0.7530891245109903
# 9  0.7530891722720766
# 10  0.753089163665594
# 11  0.7530891652164704
# 12  0.7530891649370046
# 13  0.7530891649873639
# 14  0.7530891649782893
# 15  0.7530891649799245
# 16  0.7530891649796299
# 17  0.7530891649796829
# 18  0.7530891649796734
# 19  0.753089164979675
# 20  0.7530891649796747
# 21  0.7530891649796748

# %%
f(alpha_sec)
# Out:
# 0.0

# %% [markdown]
# # Méthode de newthon

# %%
def newton(f,fp,x0):
    g=lambda x:x-f(x)/fp(x)
    ptfixegen=point_fixe(g,x0)
    while True:
        yield next(ptfixegen)

# %%
fp=lambda x:-x*np.exp(-x**2/2)-1

# %%
ntn=newton(f,fp,0)
x_ntn=[]
try:
    for i in range(40):
        alpha_nt=next(ntn)
        x_ntn.append(alpha)
        print(str(i)+"  "+str(alpha_nt))
except:
    pass
# Out:
# 0  1.0
# 1  0.7550813375962908
# 2  0.7530895752578439
# 3  0.7530891649796924
# 4  0.7530891649796748

# %%
plt.plot()
plt.plot(range(len(x_ntn)),x_ntn)
plt.plot(range(len(x_sec)),x_sec)
plt.plot(range(len(x_ptf)),x_ptf)

# %%
# create a figure and axes
fig = plt.figure(figsize=(12,8))
ax1 = plt.subplot(1,1,1)   
# set up the subplots as needed
ax1.set_xlim(( 0, 20))            
ax1.set_ylim((0, 1))
ax1.set_xlabel('x')
ax1.set_ylabel('y')
#fixed
line1, = ax1.plot(range(min(20,len(x_dicho))),x_dicho[:20],'r', lw=2)
line2, = ax1.plot(range(len(x_ntn)),x_ntn[:20], 'y', lw=2)
line3, = ax1.plot(range(min(20,len(x_ptf))),x_ptf[:20],'g', lw=2)
line4, = ax1.plot(range(min(20,len(x_sec))),x_sec[:20],'b', lw=2)

lignes,=ax1.plot([],[],'')
pt1, = ax1.plot([],[], 'ro', ms=10)
# create objects that will change in the animation. These are
# initially empty, and will be given new values for each frame
# in the animation.
txt_title = ax1.set_title('Vitesse de converege des méthodes')
ax1.legend(['Méthode de dichotomie','Méthode de newton','Méthode de point fixe','Méthode de la secante'])

# %%
e_ntn=np.abs(np.array(x_ntn[1:])-np.array(x_ntn[:-1]))
e_sec=np.abs(np.array(x_sec[1:])-np.array(x_sec[:-1]))
e_ptf=np.abs(np.array(x_ptf[1:])-np.array(x_ptf[:-1]))
e_dicho=np.abs(np.array(x_dicho[1:])-np.array(x_dicho[:-1]))

# %%
# create a figure and axes
fig = plt.figure(figsize=(12,8))
ax1 = plt.subplot(1,1,1)   
# set up the subplots as needed
ax1.set_xlim(( 0, 20))            
ax1.set_ylim((0, 0.4))
ax1.set_xlabel('x')
ax1.set_ylabel('y')
#fixed
line1, = ax1.plot(range(min(20,len(e_dicho))),e_dicho[:20],'r', lw=2)
line2, = ax1.plot(range(len(e_ntn)),e_ntn[:20], 'y', lw=2)
line3, = ax1.plot(range(min(20,len(e_ptf))),e_ptf[:20],'g', lw=2)
line4, = ax1.plot(range(min(20,len(e_sec))),e_sec[:20],'b', lw=2)

lignes,=ax1.plot([],[],'')
pt1, = ax1.plot([],[], 'ro', ms=10)
# create objects that will change in the animation. These are
# initially empty, and will be given new values for each frame
# in the animation.
txt_title = ax1.set_title('L\'erreur absolue et  Vitesse de converege des méthodes')
ax1.legend(['Méthode de dichotomie','Méthode de newton','Méthode de point fixe','Méthode de la secante'])
